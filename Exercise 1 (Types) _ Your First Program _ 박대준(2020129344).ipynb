# %%
# Exercise 1 (Types) : Your First Program
# 박대준 (2020129344)

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("Hello, World!") # Print the traditional hello world
# Out:
# Hello, World!
