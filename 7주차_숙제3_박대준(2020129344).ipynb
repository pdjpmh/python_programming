# %% [markdown]
# <a href="https://colab.research.google.com/github/pdjpmh/python_programming/blob/main/7%EC%A3%BC%EC%B0%A8_%EC%88%99%EC%A0%9C3_%EB%B0%95%EB%8C%80%EC%A4%80(2020129344).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Use a variable q to store the column Rating as a dataframe

import pandas as pd

from google.colab import drive
drive.mount('/content/gdrive')

csv_path = '/content/gdrive/My Drive/Colab Notebooks/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)

q = df[['Rating']]
q
# Out:
# Mounted at /content/gdrive
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
# Assign the variable q to the dataframe that is made up of the column Released and Artist:

q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
# Access the 2nd row and the 3rd column of df:

df.iloc[1, 2]
# Out:
# 1980
